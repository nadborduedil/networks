i feel like a goat for eating this. Still tasty though
The chocolate ball was nice
The rating explanation text is somewhat impartial today, and rightly so.


Potatoes fantastic. Chicken needs flavour. Or sauce.

Despite the false alarm, le coq delivered.
As well as the usual high standards that we have come to expect from Le Coq's chicken and potatoes, the veggie option (a.k.a the side dish) was excellent too.
Party in my mouth and you're all invited.
A little bit of France

Not a fan
Food tasted good but it gets minus points for small portion and being surprise falafel.

"""

# %%
s2 = """
this lunch gave me cancer
i loved it so much, we're eloping together

This lunch killed my father
This lunch will bring peace to the Middle East


If lunches were people this one would be the retarded offspring of Hitler and another Hitler
If lunches were people this one would make cannibalism fun again


This lunch has destroyed everything I have ever loved
Through this lunch: my diabetes is cured, I learned to appreciate simple things in life, I no longer need glasses and somehow can now play the violin


Most miserable lunch since flight 571
Best lunch since sliced bread


It's like Hitler in your mouth
Better than coke


It was the Ringo of lunches
I wanna have babies with this lunch


This lunch wears a shirt with boobs on it
This lunch lands probes on comets

This lunch is responsible for serious violations of human rights and suppression of democratic opposition.
This lunch is a beacon of hope in these dark and desperate times .

It lurks in the darkest recesses of the human mind
This lunch is what separates us from animals

This lunch sucks donkey balls
This lunch tenderly caresses donkey balls

biohazard
lunch of champions


I once had a compost heap that was better
Technically it IS food


Biggest disappointment since Phantom Menace
Almost as good as cock


This lunch kicks your sit on the airplane
This lunch changes lanes to let faster lunches pass him


This lunch shows that what doesn't kill you makes you wanna puke
This lunch shows that the best things in life come in transparent plastic boxes

Looked and tasted like someone sat on it for a long time
And that's the way my mum always makes them! Love it!


Karma is a bitch 
Must have saved some orphans in a previous life to deserve this


This lunch blurs the boundary between the packaging and the food
Why, I love me some cheese flavored soggy carboard!

Get a grip on yourselves people, it's just chicken.
Ranks in the top 10 penis-themed meals I've had this week. 


This lunch is what comes out of the business end of a human centipede after you feed it goat droppings
Does not taste nearly as bad as it looks


James K. Polk of lunches
Teddy Roosevelt of lunches

"""

# %%
# %matplotlib inline
s = s1 + s2 + s3
wolunch = s.replace("lunch", "").replace("Lunch", "").replace("lunches", "").replace("Lunches", "").replace("es", "")
wogoodlunch = wolunch.replace("good", "").replace("Good", "")
wofood = wogoodlunch.replace("food", "").replace("Food", "")

# %%
text = s
text = wolunch
# text = wogoodlunch
# text = wofood
from os import path
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from scipy.misc import imread

# Read the whole text.
# text = open(path.join(d, 'constitution.txt')).read()
chicken_mask = imread("chick3.png")
wordcloud = WordCloud(font_path="/Library/Fonts/AppleGothic.ttf",  mask=chicken_mask, 
                      width=1000, height=1000).generate(text)
wordcloud.to_file("lecoq.png")
# Open a plot of the generated image.
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
plt.imshow(wordcloud, shape=(40, 40))
plt.axis("off")
plt.show()

# %%
"""
Masked wordcloud
================
Using a mask you can generate wordclouds in arbitrary shapes.
"""

from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS


# Read the whole text.
text = s

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = imread("chicken.jpg")

wc = WordCloud(font_path="/Library/Fonts/Osaka.ttf", background_color="white", max_words=2000, mask=alice_mask,
               stopwords=STOPWORDS.add("said"))
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "lecoq.png"))

# show
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2938f53f10bf> in <module>()
#      23                stopwords=STOPWORDS.add("said"))
#      24 # generate word cloud
# ---> 25 wc.generate(text)
#      26
#      27 # store to file
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/wordcloud/wordcloud.pyc in generate(self, text)
#     311         """
#     312         self.process_text(text)
# --> 313         self.fit_words(self.words_)
#     314         return self
#     315
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/wordcloud/wordcloud.pyc in fit_words(self, words)
#     191                 # find possible places using integral image:
#     192                 result = query_integral_image(integral, box_size[1] + self.margin,
# ...
